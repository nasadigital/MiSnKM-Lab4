# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.read_edgelist('tedges.txt')

# %%
kc_communities = list(nx.algorithms.community.k_clique_communities(G, 3))

# %%
community_color = {}
cr_color = 2
for i in kc_communities:
    # print(len(i))
    for j in i:
        community_color[j] = cr_color
    cr_color += 1
color_ar = []
for i in G.nodes():
    if i in community_color:
        color_ar.append(community_color[i])
    else:
        color_ar.append(100)
print(cr_color)
# Out:
# 50

# %%
G_pos = nx.read_edgelist('tedges.txt')
with open('tedges.txt') as f:
    lines = f.readlines()
    for line in lines:
        ar = line.rstrip().split(' ')
        if ar[0] not in community_color or ar[1] not in community_color:
            if G_pos.has_edge(ar[0], ar[1]):
                G_pos.remove_edge(ar[0], ar[1])
            continue
        if community_color[ar[0]] != community_color[ar[1]]:
            if G_pos.has_edge(ar[0], ar[1]):
                G_pos.remove_edge(ar[0], ar[1])
pos = nx.spring_layout(G_pos)  # compute graph layout
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx_nodes(G, pos, node_size=10, cmap=plt.cm.RdYlBu, node_color=color_ar)
nx.draw_networkx_edges(G, pos, alpha=0.3)
plt.show(G)

# %%
name_to_id = {}
file = open('tedges_snap.txt','w') 
 
with open('tedges.txt') as f:
    lines = f.readlines()
    for line in lines:
        ar = line.rstrip().split(' ')
        if ar[0] not in name_to_id:
            name_to_id[ar[0]] = len(name_to_id)
        if ar[1] not in name_to_id:
            name_to_id[ar[1]] = len(name_to_id)
        file.write(str(name_to_id[ar[0]]) + ' ' + str(name_to_id[ar[1]]) + '\n')
    
file.close()

# %%
gn_communities_i = nx.algorithms.community.centrality.girvan_newman(G)
gn_communities = tuple(c for c in next(gn_communities_i))

# %%
community_color = {}
cr_color = 2
for i in gn_communities:
    # print(len(i))
    for j in i:
        community_color[j] = cr_color
    cr_color += 1
color_ar = []
for i in G.nodes():
    if i in community_color:
        color_ar.append(community_color[i])
    else:
        color_ar.append(15)
print(cr_color)
# Out:
# 5

# %%
G_pos = nx.read_edgelist('tedges.txt')
with open('tedges.txt') as f:
    lines = f.readlines()
    for line in lines:
        ar = line.rstrip().split(' ')
        if ar[0] not in community_color or ar[1] not in community_color:
            if G_pos.has_edge(ar[0], ar[1]):
                G_pos.remove_edge(ar[0], ar[1])
            continue
        if community_color[ar[0]] != community_color[ar[1]]:
            if G_pos.has_edge(ar[0], ar[1]):
                G_pos.remove_edge(ar[0], ar[1])
pos = nx.spring_layout(G_pos)  # compute graph layout
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx_nodes(G, pos, node_size=10, cmap=plt.cm.RdYlBu, node_color=color_ar)
nx.draw_networkx_edges(G, pos, alpha=0.3)
plt.show(G)

# %%
G_F = nx.read_edgelist('fedges.txt')

# %%
kc_communities_f = list(nx.algorithms.community.k_clique_communities(G_F, 4))

# %%
community_color_f = {}
cr_color_f = 2
for i in kc_communities_f:
    for j in i:
        kc_communities_f[j] = cr_color_f
    cr_color_f += 1
color_ar_f = []
for i in G_F.nodes():
    if i in community_color_f:
        color_ar_f.append(community_color_f[i])
    else:
        color_ar_f.append(100)
print(cr_color_f)

# %%
G_pos_f = nx.read_edgelist('fedges.txt')
with open('tedges.txt') as f:
    lines = f.readlines()
    for line in lines:
        ar = line.rstrip().split(' ')
        if ar[0] not in community_color_f or ar[1] not in community_color_f:
            if G_pos_f.has_edge(ar[0], ar[1]):
                G_pos_f.remove_edge(ar[0], ar[1])
            continue
        if community_color_f[ar[0]] != community_color_f[ar[1]]:
            if G_pos_f.has_edge(ar[0], ar[1]):
                G_pos_f.remove_edge(ar[0], ar[1])
pos_f = nx.spring_layout(G_pos_f)  # compute graph layout
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx_nodes(G_F, pos_f, node_size=10, cmap=plt.cm.RdYlBu, node_color=color_ar_f)
nx.draw_networkx_edges(G_F, pos_f, alpha=0.3)
plt.show(G_F)

# %%
gn_communities_i_f = nx.algorithms.community.centrality.girvan_newman(G_F)
gn_communities_f = tuple(c for c in next(gn_communities_i_f))

# %%
community_color_f = {}
cr_color_f = 2
for i in kc_communities_f:
    for j in i:
        kc_communities_f[j] = cr_color_f
    cr_color_f += 1
color_ar_f = []
for i in G_F.nodes():
    if i in community_color_f:
        color_ar_f.append(community_color_f[i])
    else:
        color_ar_f.append(100)
print(cr_color_f)
# Out:
# 5

# %%
G_pos_f = nx.read_edgelist('fedges.txt')
with open('tedges.txt') as f:
    lines = f.readlines()
    for line in lines:
        ar = line.rstrip().split(' ')
        if ar[0] not in community_color_f or ar[1] not in community_color_f:
            if G_pos_f.has_edge(ar[0], ar[1]):
                G_pos_f.remove_edge(ar[0], ar[1])
            continue
        if community_color_f[ar[0]] != community_color_f[ar[1]]:
            if G_pos_f.has_edge(ar[0], ar[1]):
                G_pos_f.remove_edge(ar[0], ar[1])
pos_f = nx.spring_layout(G_pos_f)  # compute graph layout
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx_nodes(G_F, pos_f, node_size=10, cmap=plt.cm.RdYlBu, node_color=color_ar_f)
nx.draw_networkx_edges(G_F, pos_f, alpha=0.3)
plt.show(G_F)
